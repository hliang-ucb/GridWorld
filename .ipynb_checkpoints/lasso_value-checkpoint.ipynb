# %% [markdown]
# Value prediction using lasso regression

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import pandas as pd
import pynwb
import glob
import os
from pathlib import Path 

from sklearn.cluster import KMeans
from numpy import linalg as LA
import statsmodels.api as sm
from scipy.stats import nbinom
from scipy import stats
from scipy import optimize
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import average_precision_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit
from scipy.optimize import differential_evolution
from scipy.stats import ttest_rel
from scipy.stats import norm
from scipy.stats import f
from scipy.stats import chi2
from scipy import signal
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
import matplotlib
from sklearn.metrics import confusion_matrix
import matplotlib.gridspec as gridspec
import joblib
import pickle
from sklearn import linear_model
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold
from statsmodels.tools.tools import add_constant

# load custom functions
import load_data
import graph
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sz1 = 12
sz2 = 16
sns.set(style="ticks", rc={"lines.linewidth": 1})
matplotlib.rc('xtick', labelsize=sz1) 
matplotlib.rc('ytick', labelsize=sz1) 
matplotlib.rc('axes', labelsize=sz1)  
matplotlib.rc('axes', titlesize=sz1)  
matplotlib.rc('figure', titlesize=sz2)
matplotlib.rc('legend', fontsize=sz1) 
matplotlib.rc('legend', title_fontsize=sz1)
matplotlib.rcParams['axes.spines.right'] = False
matplotlib.rcParams['axes.spines.top'] = False

# %%
def predict_value_add_noise(df, FR, ntrials=1000, w=100, slide=50, kfold=10, random_state=42,noise_level=10):
    
    """
    Optimized version of predict_value using StratifiedKFold and sklearn utilities.
    """
    
    # Precompute parameters
    timestamps = np.arange(w, 1000 - w + slide, slide)
    
    # Assign FR into dataframe
    df = df.copy()
    df['Neural'] = list(FR)
    df.loc[df.graph_distance > 2, 'graph_distance'] = 3
    
    # Stratified KFold for balanced splits across graph distances
    skf = StratifiedKFold(n_splits=kfold, shuffle=True, random_state=random_state)
    
    # Extract features and labels
    X = np.stack(df['Neural'].values)
    y = df['graph_distance'].values.astype(int)
    y_test_all = np.zeros(len(y))
    pred_value = np.ones((len(y),len(timestamps),noise_level))*np.nan
    
    # Model
    lasso_cv = make_pipeline(StandardScaler(),
        LassoCV(cv=5, random_state=random_state, n_alphas=100))
    
    for fold_idx, (train_idx, test_idx) in enumerate(skf.split(X, y)):
        
        # Bootstrapped training set sampling
        train_boot_idx = np.random.choice(train_idx, size=ntrials, replace=True)
        
        X_train, y_train = X[train_boot_idx], y[train_boot_idx]
        X_test, y_test = X[test_idx], y[test_idx]
        
        # Store y_test for later correlation computation
        y_test_all[test_idx] = y_test
        
        
        for ti, t in enumerate(timestamps):
            
            # Average activity across window for each trial
            X_train_win = X_train[:, t - w:t + w, :].mean(axis=1)
            X_test_win = X_test[:, t - w:t + w, :].mean(axis=1)
            
            # Train LassoCV to predict graph distance

            if X_train_win.shape[1] == 0 or np.isnan(X_train_win).any() or np.isnan(y_train).any():
                continue
            if np.allclose(X_train_win.std(axis=0), 0):
                continue
            
            try:
                lasso_cv.fit(X_train_win, y_train)
                # introduce 5 levels of gaussian noise into FR, predict values for each noise level
                for mm in range(noise_level):
                    pred_value[test_idx,ti,mm] = lasso_cv.predict(X_test_win + np.random.normal(loc=0.0, scale=X_test_win*0.2*mm))
            except ValueError as e:
                print(f"Skipping t={t}: {e}")
                continue
                  
    
    # Compute R^2 (squared correlation coefficient) over timestamps
    # rsquare = np.array([
    #     np.corrcoef(pred_value[t_idx, :], y_test_all)[0, 1] ** 2
    #     for t_idx in range(len(timestamps))
    # ])

    # rsquare = np.array([
    #     r2_score(pred_value[:, t_idx], y_test_all)
    #     for t_idx in range(len(timestamps))
    # ])


    return pred_value, y_test_all

# %%
def predict_value(
    df,
    FR,                     # shape: (n_trials, T, n_neurons)
    ntrials=1000,
    w=200,
    slide=100,
    kfold=10,
    random_state=42,
    var = 'graph_distance'
):
    """
    Decode graph_distance from population firing rates using
    sliding-window LassoCV with stratified k-fold cross-validation.

    Returns
    -------
    pred_value : (n_trials, n_timebins)
        Cross-validated predictions
    y_test_all : (n_trials,)
        True graph_distance labels
    r : (n_timebins,)
        Correlation between prediction and true label at each time bin
    model : fitted sklearn pipeline (last fold, last time bin)
    """

    rng = np.random.default_rng(random_state)

    # ---- setup ----
    timestamps = np.arange(w, FR.shape[1] - w + slide, slide)

    df = df.copy()
    df["Neural"] = list(FR)

    idx = ~np.isnan(df[var].values)
    X = np.stack(df["Neural"].values)[idx]          # (trials, T, neurons)
    y = df[var].values[idx].astype(int)

    skf = StratifiedKFold(
        n_splits=kfold,
        shuffle=True,
        random_state=random_state
    )

    pred_value = np.full((len(y), len(timestamps)), np.nan)
    y_test_all = np.zeros(len(y), dtype=int)

    model = make_pipeline(
        StandardScaler(),
        LassoCV(cv=5, n_alphas=100, random_state=random_state)
    )

    # ---- cross-validation ----
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):

        # bootstrap training trials
        boot_idx = rng.choice(train_idx, size=ntrials, replace=True)

        X_train = X[boot_idx]
        y_train = y[boot_idx]
        X_test  = X[test_idx]
        y_test  = y[test_idx]

        y_test_all[test_idx] = y_test

        for ti, t in enumerate(timestamps):

            X_train_win = X_train[:, t-w:t+w, :].mean(axis=1).astype(np.float64)
            X_test_win  = X_test[:,  t-w:t+w, :].mean(axis=1).astype(np.float64)

            # safety checks
            if np.isnan(X_train_win).any():
                continue
            if np.allclose(X_train_win.std(axis=0), 0):
                continue

            model.fit(X_train_win, y_train)
            pred_value[test_idx, ti] = model.predict(X_test_win)

    # ---- performance metric ----
    r = np.array([
        np.corrcoef(pred_value[:, ti], y_test_all)[0, 1]
        for ti in range(len(timestamps))
    ])

    return pred_value, y_test_all, r, model

# %%
def cross_predict_value(
    df,
    FR,                     # shape: (n_trials, T, n_neurons)
    ntrials=1000,
    w=200,
    slide=100,
    kfold=10,
    random_state=42,
    var = 'graph_distance'
):
    """
    Decode graph_distance from population firing rates using
    sliding-window LassoCV with stratified k-fold cross-validation.

    Returns
    -------
    pred_value : (n_trials, n_timebins)
        Cross-validated predictions
    y_test_all : (n_trials,)
        True graph_distance labels
    r : (n_timebins,)
        Correlation between prediction and true label at each time bin
    model : fitted sklearn pipeline (last fold, last time bin)
    """

    rng = np.random.default_rng(random_state)

    # ---- setup ----
    timestamps = np.arange(w, FR.shape[1] - w + slide, slide)

    df["Neural"] = list(FR)
    df = df.iloc[~np.isnan(df[var].values)]

    train_df = df.query('trialerror==0')
    test_df = df.query('trialerror==1')
  
    X_train = np.stack(train_df["Neural"].values)         # (trials, T, neurons)
    y_train = train_df[var].values.astype(int)
    X_test = np.stack(test_df["Neural"].values)         # (trials, T, neurons)
    y_test = test_df[var].values.astype(int)
    
    pred_value = np.full((len(y_test), len(timestamps)), np.nan)

    model = make_pipeline(
        StandardScaler(),
        LassoCV(cv=5, n_alphas=100, random_state=random_state)
    )


    for ti, t in enumerate(timestamps):

        X_train_win = X_train[:, t-w:t+w, :].mean(axis=1).astype(np.float64)
        X_test_win  = X_test[:,  t-w:t+w, :].mean(axis=1).astype(np.float64)

        # safety checks
        if np.isnan(X_train_win).any():
            continue
        if np.allclose(X_train_win.std(axis=0), 0):
            continue

        model.fit(X_train_win, y_train)
        pred_value[:, ti] = model.predict(X_test_win)

    # ---- performance metric ----
    r = np.array([
        np.corrcoef(pred_value[:, ti], y_test)[0, 1]
        for ti in range(len(timestamps))
    ])

    return pred_value, y_test, r, model

# %%
def create_grid(n,barriers=[],teleports=[]):

    # create n*n grid, transition matrix
    T = np.zeros((n*n,n*n))
    block = np.diag(np.ones(n-1), k=1) + np.diag(np.ones(n-1), k=-1)
    
    for c in range(n):
        T[c*n:(c+1)*n,c*n:(c+1)*n] = block
        cols = np.arange(c, n*n, n)  
        row_idx, col_idx = np.meshgrid(cols, cols, indexing='ij')  # shape (4, 4)
        T[row_idx, col_idx] = block

    if len(barriers)>0:
        for barrier in barriers:
            T[barrier[0],barrier[1]]=0
            T[barrier[1],barrier[0]]=0

    if len(teleports)>0:
        for teleport in teleports:
            T[teleport[0],teleport[1]]=1
            T[teleport[1],teleport[0]]=1  
    
    return T


def distance_matrix(T):
    
    # calculate distance 
    n_state = T.shape[0]
    D=np.zeros((n_state,n_state))
    step=0
    connected = np.eye(n_state)
    nsteps = np.eye(n_state)

    if np.sum(T.mean(axis=0)==0)>0:

        D = np.nan    # check if all the nodes are reachable

    else:
    
        while connected.mean()<1:
        
            step=step+1
            nsteps = np.dot(nsteps,T)*(1-connected)
        
            D[nsteps>0]=step
            connected[nsteps>0]=1

    return D

T = create_grid(4,teleports=[[0,15]])
D = distance_matrix(T)

# %%
def get_pre_distance(df):
    
    pre_target = []
    blocks = df.block.unique()
    
    for ii in range(len(blocks)):
        current = df[df.block==blocks[ii]]
        if ii>0:
            previous = df[df.block==blocks[ii-1]]
            pre_target.append(np.ones(len(current))*previous.target.unique()[0])
        else:
            pre_target.append(np.ones(len(current))*np.nan)
            
    pre_target = np.concat(pre_target)
    
    pre_distance = np.ones(len(df))*np.nan
    for ii in range(len(df)):
        if not np.isnan(pre_target[ii]):
            pre_distance[ii]=D[int(pre_target[ii]),int(df.node.values[ii])]
            if pre_distance[ii]>3:
                pre_distance[ii]=3

    df['pre_distance'] = np.array(pre_distance)
    df.loc[df.pre_distance > 2, "pre_distance"] = 3

    return df

# %%
# navigation trials cross-validation

ses_info = {'session':['031723','032823','033123','032023','040423','040723','050824',  # Bart
               '101124', '100324', '092124', '092324', '092524', '100124','100924'],
           'animal': ['Bart']*7+['London']*7}
all_sessions = pd.DataFrame(ses_info)  # London
y_hat_all = []
all_r = []
all_df = pd.DataFrame()

# generic_rsquare = np.zeros((2,len(all_sessions),17))
# specific_rsquare = np.zeros((2,len(all_sessions),4,17))

for ii in range(len(all_sessions)):

    session = all_sessions.iloc[ii].session
    animal = all_sessions.iloc[ii].animal
    print(animal, session)

    nwbfile = load_data.load_nwbfile(animal, session)
    trial_df = nwbfile.intervals['trials'].to_dataframe().query('trialerror==0')
    trial_df['trial_in_block'] = trial_df.groupby('block').cumcount()
    
    DATA_DIR, FIG_DIR = load_data.initiate_directory(animal, session)

    for region in ['HPC','OFC']:

        results = load_data.load_beh_neural(animal, session, region,'action_on','(trialerror==0)')
        spikes, df, unitNames = results['spikes'], results['beh'], results['unitNames']
        df.loc[df.graph_distance > 2, "graph_distance"] = 3
        df = get_pre_distance(df)
        df = df.merge(trial_df[['trial','trial_in_block']])
    
        y_hat, _, r, _ = predict_value(df.copy(), spikes.copy(),kfold=10, var='graph_distance')
        y_hat_all.append(y_hat)
        all_r.append(r)
        df['value_pred'] = 4 - y_hat[:,5]
        
        y_hat, _, r, _ = predict_value(df.copy(), spikes.copy(),kfold=10, var='pre_distance')
        y_hat_all.append(y_hat)
        all_r.append(r)
        df.loc[~np.isnan(df['pre_distance']),'pre_value_pred'] = 4 - y_hat[:,5]
    
        df['animal'] = animal
        df['region'] = region
        all_df = pd.concat([all_df,df])
# Out:
# Bart 031723
# Building Spike Table
# 1499it [00:00, 3943.06it/s]
# Building Spike Table
# 1499it [00:00, 3810.27it/s]
# Bart 032823
# Building Spike Table
# 1860it [00:00, 3613.67it/s]
# Building Spike Table
# 1860it [00:00, 2712.24it/s]
# Bart 033123
# Building Spike Table
# 2067it [00:00, 3461.54it/s]
# Building Spike Table
# 2067it [00:00, 3841.91it/s]
# Bart 032023
# Building Spike Table
# 2278it [00:00, 4337.98it/s]
# Building Spike Table
# 2278it [00:00, 4632.72it/s]
# Bart 040423
# Building Spike Table
# 2452it [00:00, 3866.27it/s]
# Building Spike Table
# 2452it [00:00, 3453.30it/s]
# Bart 040723
# Building Spike Table
# 2093it [00:00, 4814.77it/s]
# Building Spike Table
# 2093it [00:00, 3782.97it/s]
# Bart 050824
# Building Spike Table
# 1383it [00:00, 1490.24it/s]
# Building Spike Table
# 1383it [00:00, 1477.60it/s]
# London 101124
# Building Spike Table
# 2545it [00:01, 2148.28it/s]
# Building Spike Table
# 2545it [00:01, 1534.65it/s]
# London 100324
# Building Spike Table
# 2417it [00:01, 2407.61it/s]
# Building Spike Table
# 2417it [00:01, 1832.74it/s]
# London 092124
# Building Spike Table
# 2401it [00:01, 1472.89it/s]
# Building Spike Table
# 2401it [00:01, 1614.11it/s]
# London 092324
# Building Spike Table
# 2450it [00:01, 1883.85it/s]
# Building Spike Table
# 2450it [00:01, 1536.87it/s]
# London 092524
# Building Spike Table
# 2427it [00:01, 1650.23it/s]
# Building Spike Table
# 2427it [00:01, 1581.97it/s]
# London 100124
# Building Spike Table
# 2432it [00:01, 1461.35it/s]
# Building Spike Table
# 2432it [00:01, 1726.61it/s]
# London 100924
# Building Spike Table
# 2434it [00:01, 1607.34it/s]
# Building Spike Table
# 2434it [00:01, 1859.27it/s]

# %%
# train on navigation trials, test on flash trials

ses_info = {'session':['031723','032823','033123','032023','040423','040723','050824',  # Bart
               '101124', '100324', '092124', '092324', '092524', '100124','100924'],
           'animal': ['Bart']*7+['London']*7}
all_sessions = pd.DataFrame(ses_info)  # London
y_hat_all = []
cross_r = []
cross_df = pd.DataFrame()

for ii in range(len(all_sessions)):

    session = all_sessions.iloc[ii].session
    animal = all_sessions.iloc[ii].animal
    print(animal, session)

    
    DATA_DIR, FIG_DIR = load_data.initiate_directory(animal, session)

    for region in ['HPC','OFC']:

        results = load_data.load_beh_neural(animal, session, region,'action_on','(trialerror<2)')
        spikes, df, unitNames = results['spikes'], results['beh'], results['unitNames']
        df.loc[df.graph_distance > 2, "graph_distance"] = 3
        df = get_pre_distance(df)
        df.rename(columns={'trial_cumcount': 'trial_in_block'}, inplace=True)
        flash_df = df.query('trialerror==1').copy()
        
        y_hat, _, r, _ = cross_predict_value(df.copy(), spikes.copy(),kfold=10, var='graph_distance')
        y_hat_all.append(y_hat)
        cross_r.append(r)
        flash_df['value_pred'] = 4 - y_hat[:,5]

        y_hat, _, r, _ = cross_predict_value(df.copy(), spikes.copy(),kfold=10, var='pre_distance')
        y_hat_all.append(y_hat)
        cross_r.append(r)
        flash_df.loc[~np.isnan(flash_df['pre_distance']),'pre_value_pred'] = 4 - y_hat[:,5]
        
        flash_df['animal'] = animal
        flash_df['region'] = region
        cross_df = pd.concat([cross_df,flash_df])
# Out:
# Bart 031723
# Building Spike Table
# 1727it [00:00, 3356.89it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 1727it [00:00, 3161.01it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 032823
# Building Spike Table
# 2095it [00:00, 3308.09it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2095it [00:00, 2613.74it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 033123
# Building Spike Table
# 2319it [00:00, 3377.88it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2319it [00:00, 3360.30it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 032023
# Building Spike Table
# 2566it [00:00, 4297.28it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2566it [00:00, 4470.78it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 040423
# Building Spike Table
# 2746it [00:00, 3370.67it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2746it [00:00, 3265.35it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 040723
# Building Spike Table
# 2332it [00:00, 4886.97it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2332it [00:00, 3852.69it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Bart 050824
# Building Spike Table
# 1529it [00:01, 1423.67it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 1529it [00:01, 1489.13it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 101124
# Building Spike Table
# 2735it [00:01, 2053.41it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2735it [00:01, 1475.22it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 100324
# Building Spike Table
# 2597it [00:01, 2183.66it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2597it [00:01, 1819.50it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 092124
# Building Spike Table
# 2581it [00:01, 1475.02it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2581it [00:01, 1631.73it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 092324
# Building Spike Table
# 2630it [00:01, 1875.74it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2630it [00:01, 1500.92it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 092524
# Building Spike Table
# 2606it [00:01, 1665.24it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2606it [00:01, 1572.48it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 100124
# Building Spike Table
# 2614it [00:01, 1387.31it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2614it [00:01, 1709.16it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# London 100924
# Building Spike Table
# 2616it [00:01, 1597.19it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Building Spike Table
# 2616it [00:01, 1885.04it/s]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# it's not simply value is lower on the first trial
# it's more like a weighted sum of value from previous goal and current goal

# %%
## currently decoder is trained on the value according to the current block
## try to train on value according to the previous goal and see if there is correlation at the current block - 
## the caveat is that value from the previous goal is anticorrelated with the current goal

# %%
all_df['trial_in_block']=all_df['trial_in_block']+2

# %%
cross_df.groupby('pre_distance').count()
# Out:
#               Session  start_time  stop_time  trial  step  trialerror  nsteps  \
# pre_distance
# 0.0                20          20         20     20    20          20      20
# 3.0              5836        5836       5836   5836  5836        5836    5836
#
#               start  target  block  ...  spatial_distance  window_size  nodes  \
# pre_distance                        ...
# 0.0              20      20     20  ...                20           20     20
# 3.0            5836    5836   5836  ...              5836         5836   5836
#
#               use_tele  trial_in_block  value_pred  pre_value_pred  animal  \
# pre_distance
# 0.0                 20              20          20              20      20
# 3.0               5836            5836        5836            5836    5836
#
#               region  jackpot
# pre_distance
# 0.0               20        6
# 3.0             5836     2802
#
# [2 rows x 24 columns]

# %%
region = 'HPC'
y = 'value_pred'
animal = 'Bart'
variables = ['graph_distance','pre_distance']
titles=['Distance to current goal','Distance to previous goal']

if animal=='Bart':
    temp = pd.concat([all_df[(all_df.animal=='Bart')&(all_df.region==region)&(all_df.trial_in_block<7)],
                     cross_df[(cross_df.animal=='Bart')&(cross_df.region==region)&(cross_df.trial_in_block<2)&(cross_df.pre_distance==3)]])
else:
    temp = pd.concat([all_df[(all_df.animal=='London')&(all_df.region==region)&(all_df.trial_in_block<7)],
                    cross_df[(cross_df.animal=='London')&(cross_df.region==region)]])

temp['pre_distance']=temp['pre_distance'].astype('Int64')

plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(10,4.5),sharey=True)

for ii, vv in enumerate(variables):
    
    ax = axes[ii]
    
    sns.pointplot(
        data=temp,
        hue=vv,
        y=y,
        x='trial_in_block',        # <- different axes distinguished by color
        errorbar='ci',
        native_scale=True,
        markersize=8, markeredgewidth=3, palette='plasma',ax=ax
    )
    
    ax.legend(loc=(1,0.3),title='distance')
    ax.set_xlabel('Trial number')
    ax.set_xticks(np.arange(7))
    ax.set_xticklabels(['Flash 1', 'Flash 2', 'Nav 1', 'Nav 2', 'Nav 3', 'Nav 4', 'Nav 5'], rotation=45)
    ax.set_title(titles[ii],x=0.5,y=0.95)

axes[0].set_ylabel('Predicted value')
plt.tight_layout(rect=[0.05,0,0.9,0.9])
plt.suptitle(f'{animal} {region}: Value estimation',y=0.95)

plt.savefig(f'D:/Value/{animal} {region} Value prediction, block progression')

# %%
model = ols("value_pred ~ C(graph_distance) + C(graph_distance):trial_cumcount -1", 
                data=all_df[(all_df.animal=='Bart')&(all_df.trial_cumcount<5)]).fit()
print(model.params)
print(model.pvalues)
# Out:
# C(graph_distance)[0]                   3.079491
# C(graph_distance)[1]                   2.733988
# C(graph_distance)[2]                   2.490386
# C(graph_distance)[3]                   2.318318
# C(graph_distance)[0]:trial_cumcount    0.028015
# C(graph_distance)[1]:trial_cumcount    0.011283
# C(graph_distance)[2]:trial_cumcount   -0.004472
# C(graph_distance)[3]:trial_cumcount   -0.009936
# dtype: float64
# C(graph_distance)[0]                   0.000000
# C(graph_distance)[1]                   0.000000
# C(graph_distance)[2]                   0.000000
# C(graph_distance)[3]                   0.000000
# C(graph_distance)[0]:trial_cumcount    0.000001
# C(graph_distance)[1]:trial_cumcount    0.047651
# C(graph_distance)[2]:trial_cumcount    0.503668
# C(graph_distance)[3]:trial_cumcount    0.172687
# dtype: float64

# %%
model.params.values[4]
# Out:
# np.float64(0.028014701741066357)

# %%
model = ols("value_pred ~ C(graph_distance) + C(graph_distance):trial_cumcount -1", 
                data=all_df[(all_df.animal=='London')]).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             value_pred   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     1867.
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):               0.00
# Time:                        20:27:08   Log-Likelihood:                -13869.
# No. Observations:               17106   AIC:                         2.775e+04
# Df Residuals:                   17098   BIC:                         2.782e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# C(graph_distance)[0]                    3.3237      0.014    238.264      0.000       3.296       3.351
# C(graph_distance)[1]                    2.7088      0.014    194.703      0.000       2.682       2.736
# C(graph_distance)[2]                    2.3587      0.016    149.152      0.000       2.328       2.390
# C(graph_distance)[3]                    2.0720      0.018    116.727      0.000       2.037       2.107
# C(graph_distance)[0]:trial_cumcount     0.0053      0.003      1.600      0.110      -0.001       0.012
# C(graph_distance)[1]:trial_cumcount     0.0068      0.003      2.028      0.043       0.000       0.013
# C(graph_distance)[2]:trial_cumcount    -0.0027      0.004     -0.714      0.475      -0.010       0.005
# C(graph_distance)[3]:trial_cumcount    -0.0061      0.004     -1.443      0.149      -0.014       0.002
# ==============================================================================
# Omnibus:                      188.932   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              284.908
# Skew:                          -0.116   Prob(JB):                     1.36e-62
# Kurtosis:                       3.588   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def nan_corr(x, y, min_n=3):
    mask = ~np.isnan(x) & ~np.isnan(y)
    if mask.sum() < min_n:
        return np.nan
    return -np.corrcoef(x[mask], y[mask])[0, 1]

# %%
df = all_df.copy()

# Trial cutoff logic
df = df[
    ((df.animal != 'Bart') | (df.trial_cumcount < 5))
]

corr_df = (
    df
    .groupby(['animal', 'region', 'Session', 'trial_cumcount'])
    .apply(lambda g: nan_corr(g.graph_distance.values,
                              g.value_pred.values))
    .reset_index(name='r')
)

corr_df['trial_cumcount'] = corr_df['trial_cumcount']+1


plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(8,4),sharey=True)
sns.pointplot(data=corr_df[corr_df.animal=='Bart'],x='trial_cumcount',y='r',hue='region',ax=axes[0],legend=False)
sns.pointplot(data=corr_df[(corr_df.animal=='London') & (corr_df.trial_cumcount<6)],x='trial_cumcount',y='r',hue='region',ax=axes[1])

animals = ['Bart', 'London']

for ii in range(2):
    ax = axes[ii]
    ax.set_title(animals[ii])
    ax.set_xlabel('Navigation trial number')
ax.legend()

axes[0].set_ylabel('Lasso performance (r)')
plt.tight_layout(rect=[0.05,0,0.85,0.9])
plt.suptitle('Value estimation',y=0.95)
plt.savefig('D:/Value/Lasso performance in a block')
# Out:
# C:\Users\ML_4\AppData\Local\Temp\ipykernel_9232\1465176864.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: nan_corr(g.graph_distance.values,

# %%
df = all_df.copy()

# Trial cutoff logic
df = df[
    ((df.animal != 'Bart') | (df.trial_cumcount < 5))
]

corr_df = (
    df
    .groupby(['animal', 'region', 'Session', 'trial_cumcount'])
    .apply(lambda g: nan_corr(g.pre_distance.values,
                              g.pre_value_pred.values))
    .reset_index(name='r')
)

plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(8,4),sharey=True)
sns.pointplot(data=corr_df[corr_df.animal=='Bart'],x='trial_cumcount',y='r',hue='region',ax=axes[0])
sns.pointplot(data=corr_df[corr_df.animal=='London'],x='trial_cumcount',y='r',hue='region',ax=axes[1])

for ii in range(2):
    ax = axes[ii]
    ax.set_title(animal)
    ax.set_xlabel('Navigation trial number')
    ax.legend()

axes[0].set_ylabel('Lasso performance (r)')
plt.tight_layout(rect=[0.05,0,0.85,0.9])
plt.suptitle('Previous value estimation ',y=0.95)
plt.savefig('D:/Value/Lasso performance previous value in a block')
# Out:
# C:\Users\ML_4\AppData\Local\Temp\ipykernel_9232\3784708527.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: nan_corr(g.pre_distance.values,

# %%
plt.close('all')
sns.pointplot(
    data=all_df[(all_df.animal=='London')&(all_df.trial_cumcount<4)],
    x='pre_distance',
    y='value_pred',
    label='trial 1-4'
    # hue='trial_cumcount',        # <- different axes distinguished by color
    # dodge=.4, errorbar='ci',
    # marker="_", markersize=20, markeredgewidth=3, palette='plasma'
)

sns.pointplot(
    data=all_df[(all_df.animal=='London')&(all_df.trial_cumcount>3)],
    x='pre_distance',
    y='value_pred',
    label='trial 5-8'
    # hue='trial_cumcount',        # <- different axes distinguished by color
    # dodge=.4, errorbar='ci',
    # marker="_", markersize=20, markeredgewidth=3, palette='plasma'
)
plt.legend()
plt.tight_layout(rect=[0,0,0.9,0.9])
plt.ylabel('Predicted value')
plt.xlabel('Graph distance')
plt.suptitle('London',x=0.5,y=0.95)
# plt.savefig('D:/Trial/London value prediction, block early vs late, OFC')
# Out:
# Text(0.5, 0.95, 'London')

# %%
def create_grid(n,barriers=[],teleports=[]):

    # create n*n grid, transition matrix
    T = np.zeros((n*n,n*n))
    block = np.diag(np.ones(n-1), k=1) + np.diag(np.ones(n-1), k=-1)
    
    for c in range(n):
        T[c*n:(c+1)*n,c*n:(c+1)*n] = block
        cols = np.arange(c, n*n, n)  
        row_idx, col_idx = np.meshgrid(cols, cols, indexing='ij')  # shape (4, 4)
        T[row_idx, col_idx] = block

    if len(barriers)>0:
        for barrier in barriers:
            T[barrier[0],barrier[1]]=0
            T[barrier[1],barrier[0]]=0

    if len(teleports)>0:
        for teleport in teleports:
            T[teleport[0],teleport[1]]=1
            T[teleport[1],teleport[0]]=1  
    
    return T


def distance_matrix(T):
    
    # calculate distance 
    n_state = T.shape[0]
    D=np.zeros((n_state,n_state))
    step=0
    connected = np.eye(n_state)
    nsteps = np.eye(n_state)

    if np.sum(T.mean(axis=0)==0)>0:

        D = np.nan    # check if all the nodes are reachable

    else:
    
        while connected.mean()<1:
        
            step=step+1
            nsteps = np.dot(nsteps,T)*(1-connected)
        
            D[nsteps>0]=step
            connected[nsteps>0]=1

    return D

T = create_grid(4,teleports=[[0,15]])
D = distance_matrix(T)

# %%
T = create_grid(4,teleports=[[0,15]])
D = distance_matrix(T)

pre_distance_all = []

for ss, date in enumerate(all_df.Session.unique()):

    pre_target = []
    ses_df = all_df[all_df.Session==date]
    blocks = ses_df.block.unique()
    
    for ii in range(len(blocks)):
        current = ses_df[ses_df.block==blocks[ii]]
        if ii>0:
            previous = ses_df[ses_df.block==blocks[ii-1]]
            pre_target.append(np.ones(len(current))*previous.target.unique()[0])
        else:
            pre_target.append(np.ones(len(current))*np.nan)
            
    pre_target = np.concat(pre_target)
    
    pre_distance = np.ones(len(ses_df))*np.nan
    for ii in range(len(ses_df)):
        if not np.isnan(pre_target[ii]):
            pre_distance[ii]=D[int(pre_target[ii]),int(ses_df.node.values[ii])]
            if pre_distance[ii]>3:
                pre_distance[ii]=3

    pre_distance_all.append(pre_distance)
    
all_df['pre_distance'] = np.concat(pre_distance_all)

# %%
def get_pre_distance(df):
    
    pre_target = []
    blocks = df.block.unique()
    
    for ii in range(len(blocks)):
        current = df[df.block==blocks[ii]]
        if ii>0:
            previous = df[df.block==blocks[ii-1]]
            pre_target.append(np.ones(len(current))*previous.target.unique()[0])
        else:
            pre_target.append(np.ones(len(current))*np.nan)
            
    pre_target = np.concat(pre_target)
    
    pre_distance = np.ones(len(df))*np.nan
    for ii in range(len(df)):
        if not np.isnan(pre_target[ii]):
            pre_distance[ii]=D[int(pre_target[ii]),int(df.node.values[ii])]
            if pre_distance[ii]>3:
                pre_distance[ii]=3

    df['pre_distance'] = np.array(pre_distance)
    df.loc[df.pre_distance > 2, "pre_distance"] = 3

    return df

# %%
fig, ax = plt.subplots(figsize=(6,4.5))

# First axis
l1, = ax.plot(-model.params.values[1:9],
              color='darkviolet',
              label='Block(t)')

for ii in range(1,9):
    size = 150 if model.pvalues.values[ii] < 0.05 else 10
    ax.scatter(ii-1, -model.params.values[ii],
               s=size, color='darkviolet', marker='.')
ax.set_ylabel('Coefficient')


# Second axis
ax2 = ax.twinx()

l2, = ax2.plot(-model.params.values[9:],
               color='forestgreen',
               label='Block(t-1)')

for ii in range(9,17):
    size = 150 if model.pvalues.values[ii] < 0.05 else 10
    ax2.scatter(ii-9, -model.params.values[ii],
                s=size, color='forestgreen', marker='.')

# ---- combined legend ----
handles = [l1, l2]
labels = [h.get_label() for h in handles]

ax.legend(handles, labels, loc=[0.2,0.9])

# cosmetic
ax2.spines['right'].set_visible(True)
ax2.set_ylabel('Coefficient')
plt.tight_layout(rect=[0,0,1,0.9])

plt.xlabel('Trial number')
plt.suptitle('London',y=0.95)
plt.savefig('D:/Trial/London OFC, weighted sum of current and previous block')

# %%
model = ols("value_pred ~ C(trial_cumcount):graph_distance + C(trial_cumcount):pre_distance", 
                data=all_df[(all_df.animal=='London')]).fit()
                # data=all_df[(all_df.animal=='Bart')&(all_df.trial_cumcount<5)]).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             value_pred   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     772.4
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):               0.00
# Time:                        23:19:18   Log-Likelihood:                -13898.
# No. Observations:               16919   AIC:                         2.783e+04
# Df Residuals:                   16902   BIC:                         2.796e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               3.3197      0.020    169.710      0.000       3.281       3.358
# C(trial_cumcount)[0]:graph_distance    -0.4234      0.010    -44.224      0.000      -0.442      -0.405
# C(trial_cumcount)[1]:graph_distance    -0.4313      0.010    -44.483      0.000      -0.450      -0.412
# C(trial_cumcount)[2]:graph_distance    -0.4467      0.010    -46.352      0.000      -0.466      -0.428
# C(trial_cumcount)[3]:graph_distance    -0.4459      0.010    -45.969      0.000      -0.465      -0.427
# C(trial_cumcount)[4]:graph_distance    -0.4513      0.010    -44.338      0.000      -0.471      -0.431
# C(trial_cumcount)[5]:graph_distance    -0.4547      0.010    -46.700      0.000      -0.474      -0.436
# C(trial_cumcount)[6]:graph_distance    -0.4518      0.010    -47.297      0.000      -0.471      -0.433
# C(trial_cumcount)[7]:graph_distance    -0.4462      0.010    -46.254      0.000      -0.465      -0.427
# C(trial_cumcount)[0]:pre_distance      -0.0422      0.008     -5.043      0.000      -0.059      -0.026
# C(trial_cumcount)[1]:pre_distance      -0.0238      0.008     -2.831      0.005      -0.040      -0.007
# C(trial_cumcount)[2]:pre_distance      -0.0125      0.008     -1.492      0.136      -0.029       0.004
# C(trial_cumcount)[3]:pre_distance      -0.0129      0.008     -1.525      0.127      -0.030       0.004
# C(trial_cumcount)[4]:pre_distance      -0.0176      0.009     -2.071      0.038      -0.034      -0.001
# C(trial_cumcount)[5]:pre_distance      -0.0106      0.008     -1.254      0.210      -0.027       0.006
# C(trial_cumcount)[6]:pre_distance      -0.0057      0.008     -0.676      0.499      -0.022       0.011
# C(trial_cumcount)[7]:pre_distance      -0.0204      0.008     -2.423      0.015      -0.037      -0.004
# ==============================================================================
# Omnibus:                      189.453   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.660
# Skew:                          -0.123   Prob(JB):                     6.89e-62
# Kurtosis:                       3.582   Cond. No.                         9.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.close('all')
sns.pointplot(data=all_df,x='pre_distance',y='graph_distance')
# Out:
# <Axes: xlabel='pre_distance', ylabel='graph_distance'>

# %%
all_df = all_df.reset_index(drop=True)

# %%
# add gaussian noise to FR, see if that changes the mean or variance of value prediction

ses_info = {'session':['031723','032823','033123','032023','040423','040723','050824',  # Bart
               '101124', '100324', '092124', '092324', '092524', '100124','100924'],
           'animal': ['Bart']*7+['London']*7}

all_sessions = pd.DataFrame(ses_info)  # London
all_df = pd.DataFrame()
# rsquare = np.zeros((2,len(all_sessions),17))

for ii in range(1):

    session = all_sessions.iloc[ii].session
    animal = all_sessions.iloc[ii].animal
    print(animal, session)

    DATA_DIR, FIG_DIR = load_data.initiate_directory(animal, session)
    spikes, df, unitNames = load_data.load_beh_neural(animal, session, 'OFC','action_on','trialerror==0')
    pred, ytest = predict_value_add_noise(df.copy(), spikes.copy())
    df['value_pred'] = list(4-pred)
    all_df = pd.concat([all_df,df])

plt.close('all')

dfs = []  # to collect data for each axis

for ii in range(10):
    df_temp = df.copy()
    df_temp['value_pred'] = 4 - pred[:, 16, ii]
    df_temp['noise_level'] = str(ii)   # label each prediction source
    dfs.append(df_temp)

# Combine all into one long dataframe
df_all = pd.concat(dfs, ignore_index=True)

# Drop NaNs (if any)
df_all = df_all.dropna(subset=['graph_distance', 'value_pred'])

# Now you can easily compare across axes

sns.stripplot(
    data=df_all,
    x='graph_distance',
    y='value_pred',
    hue='noise_level',        # <- different axes distinguished by color
    dodge=True, alpha=.2, legend=False, palette='plasma'
)

sns.pointplot(
    data=df_all,
    x='graph_distance',
    y='value_pred',
    hue='noise_level',        # <- different axes distinguished by color
    dodge=.4, linestyle="none", errorbar='ci',
    marker="_", markersize=20, markeredgewidth=3, palette='plasma'
)

plt.ylabel('Lasso estimate')
plt.xlabel('Distance to the goal')
plt.title('OFC value estimates, gaussian noise')
plt.savefig('D:/Figures/OFC value estimates, gaussian noise')

# %%
df['length']=[graph.distance(df.start.values[i],df.target.values[i]) for i in range(len(df))]

# %%
# df['value_pred'] = pred[:,16]
value_heatmap = df.groupby(['step','nsteps'])['value_pred'].mean().reset_index().pivot(index='step', columns='nsteps', values='value_pred')
sns.heatmap(4-value_heatmap,vmin=1.5,vmax=3.5,cmap='Blues')
# Out:
# <Axes: xlabel='nsteps', ylabel='step'>

# %%
timestamps = np.arange(100, 950, 50)
plt.close('all')

fig, ax = plt.subplots(figsize=(6, 5))

# --- First group: First step (Blues)
colors1 = sns.color_palette('Blues_r', 4)
first_step_lines = []
for ii in range(4):
    line, = ax.plot(
        timestamps,
        4 - pred[(ytest == ii) & (df.step == 0), :].mean(axis=0),
        color=colors1[ii],
        label=f'Value = {4 - ii}'
    )
    first_step_lines.append(line)

# --- Second group: All steps (Reds)
colors2 = sns.color_palette('Reds_r', 4)
all_steps_lines = []
for ii in range(4):
    line, = ax.plot(
        timestamps,
        4 - pred[(ytest == ii), :].mean(axis=0),
        color=colors2[ii],
        label=f'Value = {4 - ii}'
    )
    all_steps_lines.append(line)

# --- First legend: First step (Blues)
legend1 = ax.legend(handles=first_step_lines, title='First step', loc='lower left')

# --- Second legend: All steps (Reds)
legend2 = ax.legend(handles=all_steps_lines, title='All steps', loc='lower right')

# Important: add the first legend back to the Axes
ax.add_artist(legend1)

# --- Axis labels and limits
ax.set_ylabel('Value estimates')
ax.set_xlabel('Action on')
ax.set_xlim(50, 950)
ax.set_ylim(1, 3.5)

plt.tight_layout()
plt.title('Session %s HPC' % session)
# plt.savefig('D:/Value/Session %s HPC' % session)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 timestamps = np.arange(100, 950, 50)
#       2 plt.close('all')
#       4 fig, ax = plt.subplots(figsize=(6, 5))
#
# NameError: name 'np' is not defined

# %%
plt.close('all')

target_idx = np.isin(df.node,[1,7,8,14])
reward_idx = df.node==df.target

plt.plot(pred[target_idx & reward_idx,:].mean(axis=0),color='r')
plt.plot(pred[target_idx & ~reward_idx,:].mean(axis=0),color='r',ls='--')


colors=sns.color_palette('Blues_r',4)
for ii in range(4):
    plt.plot(pred[(ytest==ii)&(df.step==0),:].mean(axis=0),color=colors[ii])
# Out:
# C:\Users\ML_4\AppData\Local\Temp\ipykernel_24820\2970643304.py:12: RuntimeWarning: Mean of empty slice.
#   plt.plot(pred[(ytest==ii)&(df.step==0),:].mean(axis=0),color=colors[ii])
# C:\Users\ML_4\anaconda3\Lib\site-packages\numpy\_core\_methods.py:139: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(

# %%
r2 = np.zeros(17)
for ii in range(17):
    model = sm.OLS(ytest,add_constant(pred[ii,:])).fit()
    r2[ii]=model.rsquared

# %%
# Calculate your mean traces
y1 = rsquare[1, :7, :].mean(axis=0)
y0 = rsquare[0, :7, :].mean(axis=0)

# Create figure and first axis
fig, ax1 = plt.subplots(figsize=(8, 4))

# Plot first line on left y-axis
ax1.plot(y1, color='tab:blue', label='OFC')
ax1.set_ylabel('R² (Condition 1)', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create second axis (sharing the same x-axis)
ax2 = ax1.twinx()
ax2.plot(y0, color='tab:red', label='HPC')
ax2.set_ylabel('R² (Condition 0)', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Optional: add x-label and grid
ax1.set_xlabel('Timestamps')
ax1.grid(alpha=0.3)

plt.title("R² over time — London")
plt.tight_layout()
plt.show()

# %%
def value_nav_flash(date,ss):
# split train and test for choice fixations

    ses_df = choice_df.query('Session==@date').copy()
    FR = choice_spikes[ss]
    
    # FR = (FR-np.tile(FR.mean(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1)))/ \
    #      np.tile(FR.std(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1))
    ses_df['Neural']=list(FR)
    
    balanced_df = (
        ses_df
        .groupby('graph_distance', group_keys=False)
        .apply(lambda x: x.sample(1000, replace=True, random_state=42))
        .reset_index(drop=True)
    )
    
    y = balanced_df['graph_distance'].values   # stratification variable
    X = np.arange(len(y))  # or keep as DataFrame if you prefer
    
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    train_idx, test_idx = list(skf.split(X, y))[0]
    train_df = balanced_df.iloc[train_idx]
    test_df = balanced_df.iloc[test_idx]
    
    lasso_cv = predict_value_clf(train_df, 'train', lasso_cv=[])
    choice_trained = predict_value_clf(train_df, 'predict', lasso_cv=lasso_cv)
    choice_held_out = predict_value_clf(test_df, 'predict', lasso_cv=lasso_cv)
    nav1 = predict_value_clf(test_df.query('blocktrialnumber==3'), 'predict', lasso_cv=lasso_cv)
    nav2 = predict_value_clf(test_df.query('blocktrialnumber==4'), 'predict', lasso_cv=lasso_cv)
    
    
    # predict values of target nodes in flash trials, action on
    ses_df = flash_df.query('Session==@date').copy()
    FR = flash_spikes[ss]
    
    # FR = (FR-np.tile(FR.mean(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1)))/ \
    #      np.tile(FR.std(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1))
    ses_df['Neural']=list(FR)
    
    flash1_target = predict_value_clf(ses_df.query('blocktrialnumber==1'), 'predict', lasso_cv=lasso_cv)
    flash2_target = predict_value_clf(ses_df.query('blocktrialnumber==2'), 'predict', lasso_cv=lasso_cv)
    flash1_target = np.concat([flash1_target,ses_df.query('blocktrialnumber==1').pre_distance.values.reshape(1,-1)])
    flash2_target = np.concat([flash2_target,ses_df.query('blocktrialnumber==2').pre_distance.values.reshape(1,-1)])

    # predict values of non-target nodes in flash trials
    ses_df = flash_fix_df.query('Session==@date').copy()
    FR = flash_fix_spikes[ss]
    
    # FR = (FR-np.tile(FR.mean(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1)))/ \
    #      np.tile(FR.std(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1))
    ses_df['Neural']=list(FR)
    ses_df = ses_df[ses_df.fix_node!=ses_df.target].query('duration>50')
    flash1_nontarget = predict_value_clf(ses_df.query('blocktrialnumber==1'), 'predict', lasso_cv=lasso_cv,fix=1)
    flash2_nontarget = predict_value_clf(ses_df.query('blocktrialnumber==2'), 'predict', lasso_cv=lasso_cv,fix=1)
    flash1_nontarget = np.concat([flash1_nontarget,ses_df.query('blocktrialnumber==1').pre_distance.values.reshape(1,-1)])
    flash2_nontarget = np.concat([flash2_nontarget,ses_df.query('blocktrialnumber==2').pre_distance.values.reshape(1,-1)])
    
    return choice_trained, choice_held_out, np.concatenate([flash1_target,flash1_nontarget],axis=1), np.concatenate([flash2_target,flash2_nontarget],axis=1)

# %%
def predict_value_clf(df, mode, time=np.arange(600,900), lasso_cv=[], fix=0):

    if mode == 'train':
        lasso_cv = make_pipeline(
            StandardScaler(),
            LassoCV(cv=5, random_state=42, n_alphas=100)
        )    


    if fix==0:
        timepoints, cell_num = df.iloc[0]['Neural'].shape
        
        data_all = np.concatenate([
            np.stack(df['Neural'].values),
            np.stack(df['graph_distance'].values)[:, None, np.newaxis].repeat(timepoints, axis=1)
        ], axis=2)
        
        data = data_all[:,time,:].mean(axis=1)

    if fix==1:
        data = np.concatenate([
                np.stack(df['Neural'].values),
                np.stack(df['graph_distance'].values).reshape(-1,1)
                ], axis=1)
    
    if mode == 'train':
        lasso_cv.fit(data[:,:-1],data[:,-1])
        return lasso_cv 
        
    if mode == 'predict':
        pred_value = lasso_cv.predict(data[:,:-1])
        return [data[:,-1],pred_value]

# %%
train=[]
test=[]
flash1=[]
flash2=[]

for ss,date in tqdm(enumerate(choice_df.Session.unique())):
    choice_trained, choice_held_out, flash1_value, flash2_value = value_nav_flash(date,ss)
    train.append(choice_trained)
    test.append(choice_held_out)
    flash1.append(flash1_value)
    flash2.append(flash2_value)

# %%
def leave_one_trial_out(df, FR, mode='node', ntrials = 200, w = 100, slide = 50):
    
    # decode single trial dynamics, therefore training the decoder on all the other trials
    timestamps = np.arange(w,1000-w+slide,slide)
    clf = SVC(kernel='linear',probability=True) #LogisticRegression(multi_class='multinomial',random_state=0)
 
    FR = (FR-np.tile(FR.mean(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1)))/ \
         np.tile(FR.std(axis=(0,1),keepdims=True),(FR.shape[0],FR.shape[1],1))
    df['Neural']=list(FR)

    if mode=='node':
        train_all = np.zeros((16,ntrials,FR.shape[1],FR.shape[2]+1))
            
        for node in range(16):
            
            train_set = df[df.node==node]
            index = np.random.randint(len(train_set),size=ntrials)
            train_all[node,:,:,:-1] = np.stack(train_set.iloc[index]['Neural'].values)
            train_all[node,:,:,-1] = node

    if mode=='tele':
        
        train_all = np.zeros((2,ntrials,FR.shape[1],FR.shape[2]+1))
            
        for ii,train_set in enumerate([df[df.node==15],df[df.node!=15]]):
            
            index = np.random.randint(len(train_set),size=ntrials)
            train_all[ii,:,:,:-1] = np.stack(train_set.iloc[index]['Neural'].values)
            train_all[ii,:,:,-1] = ii
    
    train = train_all[:,:,500:800,:].mean(axis=2).reshape(-1,FR.shape[2]+1)
    clf.fit(train[:,:-1],train[:,-1])      
        
    return clf
