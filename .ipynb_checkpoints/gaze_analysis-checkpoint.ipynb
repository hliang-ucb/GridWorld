# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.special import softmax
import scipy
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from scipy.io import loadmat
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN, HDBSCAN
import scipy.signal as ss

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch

from scipy.sparse.csgraph import shortest_path

from collections import defaultdict, Counter
import itertools
import warnings

import nystrom_holmqvist as NH
from gaze_pipeline import get_classified_gaze , plot_saccades, get_gaze

# %load_ext autoreload
# %autoreload 2

# %%
FIGDIR = 'D:/Newworld/Figure/'

# %% [markdown]
# #### testing

# %%
# get all the saccades and fixation info, save the data and them parse it into from maze on to joystick on or whatever behavior epoch

# %%
date = '260720'
data_dir='D:/Newworld/Data'
freq=1000

mat = loadmat(f'{data_dir}/London_{date}.mat', simplify_cells=True)
eyedata = pd.DataFrame(mat['eye'])
eventcode = pd.DataFrame(mat['eventcode'])
behavior = pd.DataFrame(mat['behavior'])

# %%
from gaze_pipeline import get_gaze

# %%
all_fixations, all_saccades = get_gaze(eyedata, eventcode, behavior, 'maze_on', 'maze_off')
# Out:
# Session threshold — onset: 255.5 deg/s, offset: 127.8 deg/s  (pooled from 294 trials, 4,993,531 samples)
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# 255.51431206870245 127.75715603435123
# ...

# %%
EVENT_CODES = {'trial_start': 9,
            'center_on': 22,
            'fixation_on': 23,
            'fail_to_fixate': 24,
            'maze_on': 25,
            'joystick_on': 26,
            'small_reward': 27,
            'reach_target': 28,
            'maze_off': 29,
            'trial_end': 18              
            }
start_code, stop_code = EVENT_CODES['maze_on'], EVENT_CODES['maze_off']

# %%
for trial in np.random.choice(200,20):
    epoch_on = int(eventcode.query('(Number==@start_code) & (Trial==@trial)').Time.values[0])
    epoch_off = int(eventcode.query('(Number==@stop_code) & (Trial==@trial)').Time.values[0])
    
    trace = eyedata.query('Trial==@trial').Eye.values[0]
    x, y = trace[:, 0], trace[:, 1]
        
    plt.close('all')
    plt.figure(figsize=(40,4))
    plt.plot(x)
    plt.plot(y)
    
    temp = all_saccades.query('Trial==@trial')
    for idx, row in temp.iterrows():
        plt.axvspan(row.t_on,row.t_off,color='g',alpha=0.1)
        
    # temp = all_fixations.query('Trial==@trial')
    # for idx, row in temp.iterrows():
    #     plt.axvspan(row.t_on,row.t_off,color='m',alpha=0.1)
    plt.xlim(epoch_on,epoch_off)
    plt.ylim(-20,20)
    plt.savefig(f'{FIGDIR}trial {trial} gaze pattern')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20568\1552991370.py:20: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   plt.xlim(epoch_on,epoch_off)

# %% [markdown]
# ## Gaze from entire trial

# %%
dates = ['260702','260703']
all_fixations = pd.DataFrame()
all_saccades = pd.DataFrame()

for date in dates:
    fixations, saccades = get_classified_gaze(date, start='maze_on', stop='maze_off')
    fixations.insert(0, 'Session', date)
    saccades.insert(0, 'Session', date)
    all_fixations = pd.concat([all_fixations,fixations])
    all_saccades = pd.concat([all_saccades,saccades])
# Out:
# Session threshold — onset: 255.5 deg/s, offset: 127.8 deg/s  (pooled from 294 trials, 4,993,531 samples)
# Session threshold — onset: 308.2 deg/s, offset: 154.1 deg/s  (pooled from 398 trials, 5,922,515 samples)
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:689: RuntimeWarning: All-NaN slice encountered
#   'v_peak':     np.nanmax(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:690: RuntimeWarning: Mean of empty slice
#   'v_mean':     np.nanmean(seg_v) if len(seg_v) else np.nan,

# %% [markdown]
# ## Gaze pattern from maze on to joystick on

# %%
dates = ['260702','260703']
all_start_fixations = pd.DataFrame()
all_start_saccades = pd.DataFrame()

for date in dates:
    fixations, saccades = get_classified_gaze(date, start='center_on', stop='maze_off')
    fixations.insert(0, 'Session', date)
    saccades.insert(0, 'Session', date)
    all_start_fixations = pd.concat([all_start_fixations,fixations])
    all_start_saccades = pd.concat([all_start_saccades,saccades])
# Out:
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:634: RuntimeWarning: All-NaN slice encountered
#   'v_peak':     np.nanmax(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:635: RuntimeWarning: Mean of empty slice
#   'v_mean':     np.nanmean(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:634: RuntimeWarning: All-NaN slice encountered
#   'v_peak':     np.nanmax(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:635: RuntimeWarning: Mean of empty slice
#   'v_mean':     np.nanmean(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:634: RuntimeWarning: All-NaN slice encountered
#   'v_peak':     np.nanmax(seg_v) if len(seg_v) else np.nan,
# C:\Users\Admin\Documents\GitHub\GridWorld\nystrom_holmqvist.py:635: RuntimeWarning: Mean of empty slice
# ...

# %% [markdown]
# ### Sanity check classified fixations and saccades

# %%
plt.close('all')
fig, ax = plt.subplots(figsize=(5, 5))
palette = {
    True:  "darkviolet",
    False: "forestgreen"
}
sns.scatterplot(data=all_fixations,x='x_mean',y='y_mean',hue='center',
    palette=palette,alpha=0.02,s=50,linewidth=0,edgecolor='none',ax=ax)

ax.set(xlim=(-15, 15),ylim=(-15, 15),
    xlabel='X (°)',ylabel='Y (°)')
ax.set_aspect('equal')

sns.despine()
plt.tight_layout()
plt.title('Fixations')
# plt.savefig(f'{FIGDIR}fixation_classification.png')
# Out:
# Text(0.5, 1.0, 'Fixations')

# %%
plot_saccades(all_saccades,line_alpha=0.005, dot_alpha=0.02)
plt.suptitle('Saccades',fontsize=20)
# plt.savefig(f'{FIGDIR}saccades_classification.png')
# Out:
# Text(0.5, 0.98, 'Saccades')

# %% [markdown]
# ### Flash vs Navigation: Fixations

# %%
all_start_fixations['Trialtype'] = 'Success'
all_start_fixations.loc[all_start_fixations.TrialError==1,'Trialtype'] = 'Fail'
all_start_fixations.loc[all_start_fixations.start_room==all_start_fixations.target_room,'Trialtype'] = 'Flash'

# %%
def tukey_table_df(tukey_result,floor=1e-10):
    """group1, group2, p-adj as a small DataFrame; tiny p-values shown as '<0.001'."""
    cols = tukey_result.summary().data[0]
    rows = tukey_result.summary().data[1:]
    tdf = pd.DataFrame(rows, columns=cols)[['group1', 'group2', 'p-adj']].copy()
    tdf['p-adj'] = [f'{p:.1e}' for p in tukey_result.pvalues]
    return tdf


def add_table(ax, tdf):
    ax.axis('off')
    tbl = ax.table(cellText=tdf.values, colLabels=tdf.columns, loc='center', cellLoc='center')
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(12)
    tbl.auto_set_column_width(col=list(range(len(tdf.columns))))
    tbl.scale(1, 1.6)

# %%
plt.close('all')
# constrained_layout (not tight_layout) -- tight_layout doesn't reliably handle
# axes that are just tables (axis('off')) mixed in with normal plot axes.
fig = plt.figure(figsize=(10, 6.5), constrained_layout=True)
gs = fig.add_gridspec(2, 2, height_ratios=[4, 2.3])

# --- Panel 1: fixations per trial ---
dep_var = 'n_fixations'
df = all_start_fixations.drop_duplicates(['Session','Trial'])
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,0])
sns.histplot(data=df, x=dep_var, hue='Trialtype', bins=np.arange(-0.5, 16.5),
             stat='probability', common_norm=False, element='step', palette='Set1', ax=ax,
             linewidth=0.5, legend=False)
ax.set_title(f'Fixations per trial',fontsize=16)
ax.set_xlabel('# Fixations')
sns.despine(ax=ax)

add_table(fig.add_subplot(gs[1,0]), tukey_table_df(tukey_n))

# --- Panel 2: duration per fixation ---
dep_var = 'duration'
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=all_start_fixations).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_d = pairwise_tukeyhsd(all_start_fixations[dep_var], all_start_fixations['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,1])
sns.histplot(data=all_start_fixations, x=dep_var, hue='Trialtype', bins=np.linspace(0, 2000, 21),
             stat='probability', common_norm=False, element='step', palette='Set1', ax=ax,
             linewidth=0.5)
ax.set_title(f'Duration per fixation',fontsize=16)
ax.set_xlabel('Duration (ms)')
sns.despine(ax=ax)

add_table(fig.add_subplot(gs[1,1]), tukey_table_df(tukey_d))

plt.savefig(f'{FIGDIR}Fixations prior to joystick onset')

# %%
counts = (
    all_start_fixations
    .groupby(['Session', 'Trial', 'center'])
    .size().rename('center_fixations')
)

session_trial_pairs = all_start_fixations[['Session', 'Trial']].drop_duplicates()
centers = pd.DataFrame({'center': all_start_fixations['center'].unique()})
full_index = pd.MultiIndex.from_frame(session_trial_pairs.merge(centers, how='cross'))

counts = counts.reindex(full_index, fill_value=0).reset_index()

group_cols = ['Session', 'Trial']
nunique_per_trial = all_start_fixations.groupby(group_cols).nunique()
trial_level_cols = [c for c in nunique_per_trial.columns if (nunique_per_trial[c] <= 1).all()]
saccade_level_cols = [c for c in all_start_fixations.columns if c not in trial_level_cols + group_cols]

trial_info = all_start_fixations.drop_duplicates(group_cols)[group_cols + trial_level_cols]
counts = counts.merge(trial_info, on=group_cols, how='left')

assert counts['Trialtype'].notna().all(), 'Some (Session, Trial) pairs in counts have no match -- check for duplicate/inconsistent trial-level values within a trial.'

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 6.5), constrained_layout=True)
gs = fig.add_gridspec(2, 2, height_ratios=[4, 2.3])

dep_var = 'center_fixations'

df = counts.query('center').copy()

model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,0])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.arange(-0.5,8.5),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5,legend=False)
ax.set_title(f'Center',fontsize=16)
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,0]), tukey_table_df(tukey_n))


df = counts.query('~center').copy()

model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,1])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.arange(-0.5,8.5),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5)
ax.set_title(f'Periphery',fontsize=16)
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,1]), tukey_table_df(tukey_n))


sns.despine()
plt.suptitle('Fixations per trial',fontsize=16)
plt.savefig(f'{FIGDIR} number of fixations prior to joystick onset, center vs periphery')

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 6.5), constrained_layout=True)
gs = fig.add_gridspec(2, 2, height_ratios=[4, 2.3])

dep_var = 'duration'

df = all_start_fixations.query('center').copy()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,0])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.linspace(0,2000,21),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5,legend=False)
ax.set_title(f'Center')
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,0]), tukey_table_df(tukey_n))

df = all_start_fixations.query('~center').copy()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,1])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.linspace(0,2000,21),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5)
ax.set_title(f'Periphery')
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,1]), tukey_table_df(tukey_n))


sns.despine()
plt.suptitle('Duration per fixation',fontsize=16)
plt.savefig(f'{FIGDIR} duration per fixations prior to joystick onset, center vs periphery')

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 6.5), constrained_layout=True)
gs = fig.add_gridspec(2, 2, height_ratios=[4, 2.3])

dep_var = 'duration'

df = all_start_fixations.query('center').copy()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,0])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.linspace(0,2000,21),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5,legend=False)
ax.set_title(f'Center')
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,0]), tukey_table_df(tukey_n))

df = all_start_fixations.query('~center').copy()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

ax = fig.add_subplot(gs[0,1])
sns.histplot(data=df,x=dep_var,hue='Trialtype',bins=np.linspace(0,2000,21),stat='probability',common_norm=False,
           element="step",palette='Set1',ax=ax,linewidth=0.5)
ax.set_title(f'Periphery')
ax.set_xlabel('Duration (ms)')

add_table(fig.add_subplot(gs[1,1]), tukey_table_df(tukey_n))


sns.despine()
plt.suptitle('Total duration of fixation per trial',fontsize=16)
plt.savefig(f'{FIGDIR} Total duration of fixations prior to joystick onset, center vs periphery')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8912\3057181415.py:35: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0,0,1,0.9])

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 6.5), constrained_layout=True)
gs = fig.add_gridspec(2, 2, height_ratios=[4, 2.3])

dep_var = 'duration'

ax = fig.add_subplot(gs[0,0])
df = all_start_fixations.query('center').copy().groupby(['Session','Trial','Trialtype']).sum().reset_index()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

sns.histplot(data=df,x=dep_var,hue='Trialtype',stat='probability',common_norm=False,bins=np.linspace(0,3000,21),
           element="step",palette='Set1',ax=ax,linewidth=0.5,legend=False)
ax.set_title(f'Center')
ax.set_xlabel('Total duration (ms)')

add_table(fig.add_subplot(gs[1,0]), tukey_table_df(tukey_n))


ax = fig.add_subplot(gs[0,1])
df = all_start_fixations.query('~center').copy().groupby(['Session','Trial','Trialtype']).sum().reset_index()
model = smf.ols(f'{dep_var} ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
anova = sm.stats.anova_lm(model, typ=2)
tukey_n = pairwise_tukeyhsd(df[dep_var], df['Trialtype'], alpha=0.05)

sns.histplot(data=df,x=dep_var,hue='Trialtype',stat='probability',common_norm=False,bins=np.linspace(0,3000,21),
           element="step",palette='Set1',ax=ax,linewidth=0.5)
ax.set_title(f'Periphery')
ax.set_xlabel('Total duration (ms)')

add_table(fig.add_subplot(gs[1,1]), tukey_table_df(tukey_n))


sns.despine()
plt.suptitle('Total duration of fixation per trial',fontsize=16)
plt.savefig(f'{FIGDIR} Total duration of fixations prior to joystick onset, center vs periphery')

# %%
counts
# Out:
#      Session  Trial  center  center_fixations event_type  maze_on  \
# 0     260702      1    True                 1   fixation     1709
# 1     260702      1   False                 2   fixation     1709
# 2     260702      3    True                 2   fixation     1433
# 3     260702      3   False                 1   fixation     1433
# 4     260702      4    True                 1   fixation     1555
# ...      ...    ...     ...               ...        ...      ...
# 1259  260703    530   False                 2   fixation     1561
# 1260  260703    531    True                 0   fixation     1948
# 1261  260703    531   False                 1   fixation     1948
# 1262  260703    533    True                 1   fixation     1684
# 1263  260703    533   False                 0   fixation     1684
#
#       joystick_on  BlockNumber  InitiatedTrialsInBlock  EngagedTrialsInBlock  \
# 0            2365            0                       0                     0
# ...

# %%
plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(10,4),sharey=True)

ax=axes[0]
sns.pointplot(data=counts[counts.Trialtype!='Flash'],x='graph_distance',y='center_fixations',hue='center',native_scale=True, 
              ax=axes[0],legend=False,palette='magma')
ax.set_xlim([0.5,6.5])
ax.set_title('Distance',fontsize=16)

ax=axes[1]
sns.pointplot(data=counts[counts.Trialtype!='Flash'],x='degree',y='center_fixations',hue='center', native_scale=True, ax=axes[1],palette='magma')
ax.set_xlim([0.5,4.5])
ax.set_xticks(np.arange(1,5))
ax.set_title('Degree',fontsize=16)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[:2], ['Periphery','Center'], frameon=False, title='')


sns.despine()

fig.tight_layout(rect=[0.05, 0, 0.9, 0.95])
plt.suptitle('Fixations pattern',fontsize=18, y=1)
plt.savefig(f'{FIGDIR} {date} Fixations pattern on distance and degree.png')

# %%
model = smf.ols(formula='center_fixations ~ 0 + C(center) + C(center):graph_distance', data=counts[counts.Trialtype!='Flash'])
results = model.fit()
print(results.summary())
print(results.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       center_fixations   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     62.13
# Date:                Sun, 05 Jul 2026   Prob (F-statistic):           3.29e-37
# Time:                        17:28:45   Log-Likelihood:                -1836.8
# No. Observations:                1146   AIC:                             3682.
# Df Residuals:                    1142   BIC:                             3702.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(10,4),sharey=True)

p2p = counts.query('~center').copy()
p2p['success']=p2p.TrialError==0

ax=axes[0]
sns.pointplot(data=p2p[p2p.Trialtype!='Flash'],x='graph_distance',y='center_fixations',hue='success',native_scale=True, ax=axes[0])
ax.set_xlim([0.5,6.5])
ax.set_title('Distance',fontsize=16)

ax=axes[1]
sns.pointplot(data=p2p[p2p.Trialtype!='Flash'],x='degree',y='center_fixations',hue='success', native_scale=True, ax=axes[1])
ax.set_xlim([0.5,4.5])
ax.set_xticks(np.arange(1,5))
ax.set_title('Degree',fontsize=16)
        
sns.despine()

fig.tight_layout(rect=[0.05, 0, 0.9, 0.95])
plt.suptitle('Fixations at periphery',fontsize=18, y=1)
plt.savefig(f'{FIGDIR} {date} Fixations periphery on distance and degree.png')

# %% [markdown]
# ### Flash vs Navigation: Saccades

# %%
counts = (
    all_start_saccades
    .groupby(['Session', 'Trial', 'direction'])
    .size().rename('n_saccades')
)

session_trial_pairs = all_start_saccades[['Session', 'Trial']].drop_duplicates()
directions = pd.DataFrame({'direction': all_start_saccades['direction'].unique()})
full_index = pd.MultiIndex.from_frame(session_trial_pairs.merge(directions, how='cross'))

counts = counts.reindex(full_index, fill_value=0).reset_index()

group_cols = ['Session', 'Trial']
nunique_per_trial = all_start_saccades.groupby(group_cols).nunique()
trial_level_cols = [c for c in nunique_per_trial.columns if (nunique_per_trial[c] <= 1).all()]
saccade_level_cols = [c for c in all_start_saccades.columns if c not in trial_level_cols + group_cols]

trial_info = all_start_saccades.drop_duplicates(group_cols)[group_cols + trial_level_cols]
counts = counts.merge(trial_info, on=group_cols, how='left')

assert counts['Trialtype'].notna().all(), 'Some (Session, Trial) pairs in counts have no match -- check for duplicate/inconsistent trial-level values within a trial.'

# %%
plt.close('all')
fig = plt.figure(figsize=(6, 6), constrained_layout=True)
gs = fig.add_gridspec(2, 2)


for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = counts.query('direction==@direction').copy()

    model = smf.ols(f'n_saccades ~ C(Trialtype, Treatment(reference="Flash"))', data=df).fit()
    anova = sm.stats.anova_lm(model, typ=2)
    tukey_n = pairwise_tukeyhsd(df['n_saccades'], df['Trialtype'], alpha=0.05)

    ax = fig.add_subplot(gs[np.divmod(n,2)])
    add_table(ax, tukey_table_df(tukey_n))
    ax.set_title(direction, fontsize=14)

plt.savefig(f'{FIGDIR} saccades prior to joystick onset, pairwise statistics')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),gridspec_kw={'wspace':0.4,'hspace':0.4})

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = counts.query('direction==@direction').copy()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='n_saccades',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, bins=np.arange(-0.5,6.5),
                 element="step",palette='Set1',ax=ax,linewidth=0.5)
    ax.set_title(direction, fontsize=14)
    ax.set_xlabel('# Saccades')

sns.despine()
plt.savefig(f'{FIGDIR} saccades prior to joystick onset')

# %%
p2p = counts[counts.direction=='periphery_to_periphery'].copy()
p2p['success'] = p2p.TrialError==0

# %%
plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(10,4),sharey=True)

ax=axes[0]
sns.pointplot(data=counts[counts.Trialtype!='Flash'],x='graph_distance',y='n_saccades',hue='direction',native_scale=True, 
              ax=axes[0],legend=False,palette='magma')
ax.set_xlim([0.5,6.5])
ax.set_title('Distance',fontsize=16)

ax=axes[1]
sns.pointplot(data=counts[counts.Trialtype!='Flash'],x='degree',y='n_saccades',hue='direction', native_scale=True, ax=axes[1],palette='magma')
ax.set_xlim([0.5,4.5])
ax.set_xticks(np.arange(1,5))
ax.set_title('Degree',fontsize=16)
        
sns.despine()

fig.tight_layout(rect=[0.05, 0, 0.9, 0.95])
plt.suptitle('Saccades pattern',fontsize=18, y=1)
plt.savefig(f'{FIGDIR} {date} Saccades pattern on distance and degree.png')

model = smf.ols(formula='n_saccades ~ 0 + C(direction) + C(direction):degree', data=counts[counts.Trialtype!='Flash'])
results = model.fit()
print(results.summary())

plt.close('all')
fig, axes = plt.subplots(1,2,figsize=(10,4),sharey=True)

ax=axes[0]
sns.pointplot(data=p2p[p2p.Trialtype!='Flash'],x='graph_distance',y='n_saccades',hue='success',native_scale=True, ax=axes[0])
ax.set_xlim([0.5,6.5])
ax.set_title('Distance',fontsize=16)

ax=axes[1]
sns.pointplot(data=p2p[p2p.Trialtype!='Flash'],x='degree',y='n_saccades',hue='success', native_scale=True, ax=axes[1])
ax.set_xlim([0.5,4.5])
ax.set_xticks(np.arange(1,5))
ax.set_title('Degree',fontsize=16)
        
sns.despine()

fig.tight_layout(rect=[0.05, 0, 0.9, 0.95])
plt.suptitle('Saccades from periphery to periphery',fontsize=18, y=1)
plt.savefig(f'{FIGDIR} {date} Saccades periphery on distance and degree.png')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex=True)

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = all_start_saccades.query('direction==@direction').copy().groupby(['Session','Trial','Trialtype']).sum().reset_index()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='distance',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, bins=np.linspace(0,80,21),
                 element="step",palette='Set1',ax=ax)
    ax.set_title(direction)
    ax.set_xlabel('Distance (visual degree)')


sns.despine()
plt.tight_layout(rect=[0,0,1,0.9])
plt.suptitle('Total saccade distance per trial',fontsize=16)
plt.savefig(f'{FIGDIR} Total saccade distance prior to joystick onset')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex=True)

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = all_start_saccades.query('direction==@direction').copy()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='v_mean',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, #bins=np.linspace(0,80,21),
                 element="step",palette='Set1',ax=ax)
    ax.set_title(direction)
    ax.set_xlabel('Distance (visual degree)')


sns.despine()
plt.tight_layout(rect=[0,0,1,0.9])
plt.suptitle('Total saccade distance per trial',fontsize=16)
# plt.savefig(f'{FIGDIR} Total saccade distance prior to joystick onset')
# Out:
# Text(0.5, 0.98, 'Total saccade distance per trial')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex=True)

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = all_start_saccades.query('direction==@direction').copy()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='distance',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, bins=np.linspace(0,30,21),
                 element="step",palette='Set1',ax=ax)
    ax.set_title(direction)
    ax.set_xlabel('Distance (visual degree)')


sns.despine()
plt.tight_layout(rect=[0,0,1,0.9])
plt.suptitle('Distance per saccade',fontsize=16)
plt.savefig(f'{FIGDIR} distance per saccades prior to joystick onset')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex=True)

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = all_start_saccades.query('direction==@direction').copy().groupby(['Trial','Trialtype']).sum()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='duration',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, bins=np.arange(0,200,10),
                 element="step",palette='Set1',ax=ax)
    ax.set_title(direction)
    ax.set_xlabel('Duration (ms)')


sns.despine()
plt.tight_layout(rect=[0,0,1,0.9])
plt.suptitle('Saccades direction prior to joystick onset',fontsize=16)
# plt.savefig(f'Session {date} saccades prior to joystick onset')
# Out:
# Text(0.5, 0.98, 'Saccades direction prior to joystick onset')

# %%
plt.close('all')
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex=True)

for n, direction in enumerate(all_start_saccades.direction.unique()):
    
    df = all_start_saccades.query('direction==@direction').copy()
    ax = axes[np.divmod(n,2)]
            
    sns.histplot(data=df,x='v_mean',hue='Trialtype',hue_order=['Flash','Fail','Success'],
                 stat='probability',common_norm=False, bins=np.arange(50,850,50),
                 element='step',palette='Set1',ax=ax)

    ax.set_title(direction)
    ax.set_xlabel('Velocity')


sns.despine()
plt.tight_layout(rect=[0,0,1,0.9])
plt.suptitle('Saccades direction prior to joystick onset',fontsize=16)
# plt.savefig(f'Session {date} saccades prior to joystick onset')
# Out:
# Text(0.5, 0.98, 'Saccades direction prior to joystick onset')

# %% [markdown]
# ## Gaze pattern during pause

# %%
dates = ['260702','260703']
beh = pd.DataFrame()

for date in dates:
    mat = loadmat(f'D:/Newworld/Data/London_{date}.mat', simplify_cells=True)
    temp = pd.DataFrame(mat['behavior'])
    temp = temp[temp.instruct==0]
    temp['BlockNumber'] = (temp['target_room'] != temp['target_room'].shift()).cumsum()
    temp.insert(0, 'Session', date)
    beh = pd.concat([beh,temp])

beh.reset_index(inplace=True,drop=True)
beh['target'] = beh.target_room - 1
beh['start'] = beh.start_room - 1
beh['current'] = beh.current_room - 1

nav = beh[beh.start!=beh.target].copy()
nav['success'] = (nav['TrialError'] == 0) * 1
room_seq = nav.groupby(['Session','Trial','target','start'])['current'].agg(list).reset_index(name='rooms')

nav_trial = nav[nav.step==1].copy()
flash_trial = beh[beh.start==beh.target].copy()

nav_trial = nav_trial.merge(room_seq,on=['Session','Trial','target','start'])
nav_trial['detour_index'] = nav_trial['minus_step'] / nav_trial['graph_distance']

# %%
# first get pauses
date = '260702'
joystick = pd.DataFrame(mat['joystick'])
joystick['Session'] = date
joystick['duration']  = joystick['Offset']-joystick['Onset']
joystick = joystick.merge(nav_trial.query('Session==@date'), on=['Session','Trial']).reset_index(drop=True)

# value 0 means joystick is not triggered
# if the last move is pause in failed trials, it is stop / last move on success trials can also be 0 so excluding that
# pauses would be 0 in the middle of a trial
joystick['lastmove'] = False
joystick['firstmove'] = False
last_idx = joystick.groupby(['Trial']).tail(1).index
first_idx = joystick.groupby(['Trial']).head(1).index
joystick.loc[last_idx, 'lastmove'] = True
joystick.loc[first_idx, 'firstmove'] = True

stops = joystick.query('(lastmove)&(Value==0)&(success==0)')
pauses = joystick.query('(~firstmove)&(~lastmove)&(Value==0)')
pauses = pauses.query('(duration>0)&(duration<3000)').reset_index(drop=True)

# %%
eyedata = pd.DataFrame(mat['eye'])

# %%
def get_joystick_trace(trial,epoch_on,epoch_off):
    
    trial_joystick = joystick[joystick.Trial==trial]
    trial_joystick = trial_joystick.query('(Offset>@epoch_on)&(Onset<@epoch_off)')
    time = []
    trace = []
    for _,row in trial_joystick.iterrows():
        onset = row.Onset
        offset = row.Offset
        time.append(np.arange(onset,offset))
        trace.append(np.ones(offset-onset)*int(str(row.Value), 2))

    return np.hstack(time), np.hstack(trace)

# %%
fix, sac = get_gaze(eyedata, pauses)

# %%
plt.close('all')

# %%
fix.query('(pause_duration>100)&(pause_duration<300)').index.values
# Out:
# array([  0,   1,   2,   3,   5,   6,   7,   9,  12,  14,  17,  18,  20,
#         22,  23,  26,  27,  28,  29,  31,  32,  33,  34,  43,  45,  53,
#         56,  57,  63,  64,  65,  72,  74,  75,  76,  77,  78,  79,  94,
#         95, 100, 103, 104, 113, 120, 128, 129, 130, 132, 143, 144, 163,
#        167, 168, 171, 172, 173, 174, 187, 188, 198, 199, 200, 201, 203,
#        204, 206, 208, 209, 212, 213, 224, 227, 228, 234, 236, 237, 241,
#        242, 244, 245, 246, 249, 250, 252, 265, 266, 267, 268, 288, 289,
#        318, 324, 325, 326, 335, 368, 369, 381, 382, 384, 420, 421, 422,
#        447, 448, 454, 455, 457, 458, 460, 465, 466, 472, 474, 475, 477,
#        481, 484, 486, 487, 488, 489, 491, 494, 495, 499, 500, 504, 505,
#        506, 509, 510, 511, 512, 514, 517, 519, 520, 549, 550, 551, 556,
#        559, 560, 562, 563, 565, 567, 568, 578, 581, 582, 583, 584, 589,
#        591, 592, 593, 594, 596, 597, 600, 602, 605, 606, 607, 608, 612,
# ...

# %%
window = 0
for idx in np.random.choice(fix.query('(pause_duration>650)&(pause_duration<1300)').index.values,20):
    row = fix.iloc[idx]
    epoch_on = row.pause_on
    epoch_off = row.pause_off
    trial = row.Trial
    time, joystick_trace = get_joystick_trace(trial,epoch_on-window,epoch_off+window)
    eye_trace = eyedata.query('Trial==@trial').Eye.values[0]

    try:
        plt.close('all')
        # plt.plot(trace)
        plt.plot(np.arange(epoch_on-window,epoch_off+window),eye_trace[epoch_on-window:epoch_off+window,:])
        plt.plot(time,joystick_trace)
        plt.xlim(epoch_on-window,epoch_off+window)
        plt.ylim(-15,15)
        # plt.axvspan(epoch_on,epoch_off,color='m',alpha=0.2)
        plt.savefig(f'{FIGDIR} pause 650-1300 Trial {trial} Row {idx}')
    except:
        print('error')

# %%
# look at if direction of gaze and joystick align

# %%
def get_gaze(eyedata, pauses, start='pause_on', stop='pause_off',window=0,
             freq=1000, xy_bound=25, v_max=1000, dur_max=2000):

    fixation_list = []
    saccade_list = []

    for trial in pauses.Trial.unique():
        
        trace = eyedata.query('Trial==@trial').Eye.values[0]
        x, y = trace[:, 0], trace[:, 1]
        result = NH.detect_saccades_NH(x, y)
        
        trial_pauses = pauses.query('Trial==@trial')
        
        for idx, row in trial_pauses.iterrows():
            try:
                epoch_on = row.Onset-window
                epoch_off = row.Offset+window
                trial_fixations = result.fixations.query('(t_off>@epoch_on) & (t_on<@epoch_off)').copy()
                trial_saccades = result.saccades.query('(t_off>@epoch_on) & (t_on<@epoch_off)').copy()

                trial_fixations[start] = row.Onset
                trial_fixations[stop] = row.Offset
                trial_fixations.insert(0, 'Trial', trial)
    
                trial_saccades[start] = row.Onset
                trial_saccades[stop] = row.Offset
                trial_saccades.insert(0, 'Trial', trial)
    
                fixation_list.append(trial_fixations)
                saccade_list.append(trial_saccades)
    
            except Exception as e:
                print(f'Trial {trial}, row {idx}: skipped ({type(e).__name__}: {e})')

    fixation_list = [df for df in fixation_list if not df.empty]
    saccade_list = [df for df in saccade_list if not df.empty]

    all_fixations = pd.concat(fixation_list, ignore_index=True)
    all_saccades = pd.concat(saccade_list, ignore_index=True)

    all_fixations['pause_duration'] = all_fixations[stop]-all_fixations[start]
    all_saccades['pause_duration'] = all_saccades[stop]-all_saccades[start]

    # trial_behavior = behavior.drop_duplicates('Trial')
    # all_fixations = all_fixations.merge(trial_behavior, on='Trial')
    # all_saccades = all_saccades.merge(trial_behavior, on='Trial')

    # all_fixations = all_fixations[
    #     (all_fixations.x_mean.abs() < xy_bound) & (all_fixations.y_mean.abs() < xy_bound)
    #     & (all_fixations.duration < dur_max)
    # ]
    # all_fixations['n_fixations'] = all_fixations.groupby('Trial')['Trial'].transform('size')
    # all_saccades = all_saccades[all_saccades.v_mean < v_max]

    return all_fixations, all_saccades

# %% [markdown]
# ## Gaze pattern while moving

# %% [markdown]
# ## Gaze pattern when entering a room
